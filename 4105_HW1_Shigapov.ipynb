# %% [markdown]
# <a href="https://colab.research.google.com/github/TreeLiquid/Intro-to-ML/blob/main/4105_HW1_Shigapov.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')

#Obtain file data
filepath = '/content/drive/My Drive/Fall-2023/Intro-to-ML/Datasets/D3.csv'
data1 = pd.DataFrame(pd.read_csv(filepath))
print(data1.head())
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#          X1        X2        X3         Y
# 0  0.000000  3.440000  0.440000  4.387545
# 1  0.040404  0.134949  0.888485  2.679650
# 2  0.080808  0.829899  1.336970  2.968490
# 3  0.121212  1.524848  1.785455  3.254065
# 4  0.161616  2.219798  2.233939  3.536375

# %%
#Value Stripping
x1 = data1.values[:, 0] #x1 array
x2 = data1.values[:, 1] #x2 array
x3 = data1.values[:, 2] #x3 array
y = data1.values[:, 3] #x4 array

#Array Lengths
m1 = len(x1)
m2 = len(x2)
m3 = len(x3)
n = len(Y)

print('X1 Length = ', m1)
print('X2 Length = ', m2)
print('X3 Length = ', m3)
print('Y Length = ', n)

print('X1 = ', x1)
print('X2 = ', x2)
print('X3 = ', x3)
print('Y = ', y)
# Out:
# X1 Length =  100
# X2 Length =  100
# X3 Length =  100
# Y Length =  100
# X1 =  [0.         0.04040404 0.08080808 0.12121212 0.16161616 0.2020202
#  0.24242424 0.28282828 0.32323232 0.36363636 0.4040404  0.44444444
#  0.48484848 0.52525252 0.56565657 0.60606061 0.64646465 0.68686869
#  0.72727273 0.76767677 0.80808081 0.84848485 0.88888889 0.92929293
#  0.96969697 1.01010101 1.05050505 1.09090909 1.13131313 1.17171717
#  1.21212121 1.25252525 1.29292929 1.33333333 1.37373737 1.41414141
#  1.45454546 1.49494949 1.53535354 1.57575758 1.61616162 1.65656566
#  1.6969697  1.73737374 1.77777778 1.81818182 1.85858586 1.8989899
#  1.93939394 1.97979798 2.02020202 2.06060606 2.1010101  2.14141414
#  2.18181818 2.22222222 2.26262626 2.3030303  2.34343434 2.38383838
#  2.42424242 2.46464646 2.5050505  2.54545455 2.58585859 2.62626263
#  2.66666667 2.70707071 2.74747475 2.78787879 2.82828283 2.86868687
#  2.90909091 2.94949495 2.98989899 3.03030303 3.07070707 3.11111111
# ...

# %%
#Matrix Prep
x_0 = np.ones((m1, 1))
X_1 = x1.reshape((m1,1))
X_2 = x2.reshape((m2,1))
X_3 = x3.reshape((m3,1))

X_1_feat = np.hstack((x_0, X_1))
X_2_feat = np.hstack((x_0, X_2))
X_3_feat = np.hstack((x_0, X_3))

#Zero Matrix
theta = np.zeros(2)
# Out:
# array([[1.        , 0.        ],
#        [1.        , 0.04040404],
#        [1.        , 0.08080808],
#        [1.        , 0.12121212],
#        [1.        , 0.16161616]])

# %%
#Linear Regression Algor.
def LR(x, y, theta):
 predictions = x.dot(theta)
 error = np.subtract(predictions, y)
 sqrE = np.square(error)
 out = J = 1 / (2 * n) * np.sum(sqrE)
 return out

# %%
#Gradient Descent Algor.
def gradD(x, y, theta, a, itr):


  return

# %%
#Independant Linear Regressions
i_X1 = LR(X_1_feat, y, theta)
i_X2 = LR(X_2_feat, y, theta)
i_X3 = LR(X_3_feat, y, theta)
print(i_X1)
print(i_X2)
print(i_X3)
# Out:
# 5.524438459196242
# 5.524438459196242
# 5.524438459196242
